# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계1 : 탐색적 데이터 분석

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **기본 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature와 중요하지 않은 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.

# %% [markdown]
# ### (2) 미션2
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# * 제공 함수 생성
#     * 변수 중요도를 시각화할 수 있는 함수를 제공합니다.
#     * 입력 :
#         * importance : 트리모델의 변수 중요도(예: model.feature_importances_)
#         * names : 변수 이름 목록(예 : x_train.columns)
#         * result_only  : 변수 중요도 순으로 데이터프레임만 return할지, 그래프도 포함할지 결정. False이면 결과 데이터프레임 + 그래프
#         * topn : 중요도 상위 n개만 표시. all 이면 전체.
#     * 출력 :
#         * 중요도 그래프 : 중요도 내림차순으로 정렬
#         * 중요도 데이터프레임 : 중요도 내림차순으로 정렬

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %%
file1 = 'data01_train.csv'
file2 = 'data01_test.csv'
file3 = 'features.csv'

# %%
data = pd.read_csv(path + file1)
test = pd.read_csv(path + file2)
features = pd.read_csv(path + file3)

# %%
# 불필요한 칼럼 삭제
data.drop('subject', axis=1, inplace=True)
test.drop('subject', axis=1, inplace=True)

# %% [markdown]
# ## 2.데이터 분석 : 기본정보 살펴보기

# %% [markdown]
# ### (1) 기본정보 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - 불러온 데이터의 형태, 기초통계량, 정보 등을 확인합니다.

# %%
#전체 데이터의 행,열 개수 확인
data.shape
# Out:
# (5881, 562)

# %%
#전체 데이터의 상위 5개 행 확인
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %%
#전체 데이터의 수치형 변수 분포 확인
data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      5881.000000                      5881.000000
# mean                          0.126955                        -0.305883
# std                           0.249176                         0.322808
# min                          -0.965725                        -0.979261
# 25%                          -0.021610                        -0.541969
# 50%                           0.133887                        -0.342923
# 75%                           0.288944                        -0.127371
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      5881.000000                  5881.000000
# mean                         -0.623548                     0.008524
# std                           0.310371                     0.339730
# min                          -0.999765                    -0.976580
# 25%                          -0.845985                    -0.122361
# 50%                          -0.712677                     0.010278
# 75%                          -0.501158                     0.154985
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           5881.000000                       5881.000000
# mean                              -0.001185                          0.009340
# std                                0.447197                          0.608190
# min                               -1.000000                         -1.000000
# 25%                               -0.294369                         -0.481718
# 50%                                0.005146                          0.011448
# 75%                                0.285030                          0.499857
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           5881.000000           5881.000000
# mean                              -0.007099             -0.491501
# std                                0.476738              0.509069
# min                               -1.000000             -1.000000
# 25%                               -0.373345             -0.811397
# 50%                               -0.000847             -0.709441
# 75%                                0.356236             -0.511330
# max                                0.996078              0.977344
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           5881.000000           5881.000000
# mean               0.059299             -0.054594
# std                0.297340              0.278479
# min               -1.000000             -0.980143
# 25%               -0.018203             -0.141555
# 50%                0.182893              0.003951
# 75%                0.248435              0.111932
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %%
#전체 데이터의 모든 변수 확인
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)

# %% [markdown]
# ### (2) 목표 변수 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - target인 'Activity'에 대해 단변량 분석을 수행합니다.
#     - 범주의 종류, 범주별 빈도수 및 비율 등

# %%
data['Activity'].value_counts()
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
data['Activity'].value_counts() / data.shape[0]
# Out:
# Activity
# LAYING                0.189594
# STANDING              0.184833
# SITTING               0.175480
# WALKING               0.169699
# WALKING_UPSTAIRS      0.145894
# WALKING_DOWNSTAIRS    0.134501
# Name: count, dtype: float64

# %%
sns.countplot(x = 'Activity', data = data)
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# ### (3) 센서 그룹 데이터: features

# %% [markdown]
# * **세부 요구사항**
#     - feature 이름에 대한 계층 구조별로 변수의 수를 카운트 해 봅시다.
#         - sensor 별 변수의 개수
#         - agg(regation) 별 변수의 개수
#         - axis 별 변수의 개수

# %%
#센서 그룹 데이터의 'sensor'변수의 값 확인
features['sensor'].value_counts()
# Out:
# sensor
# fBodyGyro               79
# fBodyAccJerk            79
# fBodyAcc                79
# tBodyAcc                40
# tGravityAcc             40
# tBodyAccJerk            40
# tBodyGyroJerk           40
# tBodyGyro               40
# tGravityAccMag          13
# tBodyAccMag             13
# tBodyGyroJerkMag        13
# tBodyGyroMag            13
# tBodyAccJerkMag         13
# fBodyAccMag             13
# fBodyBodyAccJerkMag     13
# fBodyBodyGyroMag        13
# fBodyBodyGyroJerkMag    13
# angle                    7
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'agg'변수의 값 확인
features['agg'].value_counts()
# Out:
# agg
# bandsEnergy()        126
# arCoeff()             60
# std()                 33
# mad()                 33
# max()                 33
# energy()              33
# min()                 33
# entropy()             33
# iqr()                 33
# mean()                33
# sma()                 17
# correlation()         15
# kurtosis()            13
# meanFreq()            13
# skewness()            13
# maxInds               13
# arCoeff()4             5
# arCoeff()2             5
# arCoeff()3             5
# arCoeff()1             5
# tBodyAccMean           1
# tBodyAccJerkMean       1
# tBodyGyroMean          1
# tBodyGyroJerkMean      1
# X                      1
# Y                      1
# Z                      1
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'axis'변수의 값 확인
features['axis'].value_counts()
# Out:
# axis
# X              76
# Y              76
# Z              76
# gravityMean     6
# X,2             5
#                ..
# 17,32.2         2
# 49,64.2         2
# 1,24.2          2
# 25,48.2         2
# gravity         1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ## 3.미션1 : 데이터 분석1

# %% [markdown]
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **트리 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.
# * 3) **각 feature 그룹별 중요도**도 파악해보며 EDA를 수행
#     * Feature 이름에는 계층구조를 담고 있습니다. 그렇다 보니 feature들을 적절하게 그룹으로 묶을 수 있습니다.
#     * 참고로, feature 그룹의 중요도는 개별 feature 중요도의 합으로 계산할 수 있습니다.

# %% [markdown]
# ### (1) 기본모델링 + 변수중요도 추출

# %% [markdown]
# * **세부 요구사항**
#     - 모델링을 위한 기본 전처리를 수행합니다.
#         - 주어진 데이터에서는 x, y로 나누고 train과 validation 분할 수행
#     - 트리기반 알고리즘을 이용하여 모델링을 합니다.
#         - 랜덤포레스트 권장 : 랜덤포레스트는 튜닝 없이 하이퍼파리미터의 기본값로도 적절한 성능의 모델을 생성할 수 있습니다.
#     - 변수 중요도 추출
#         - 사용자정의함수로 생성한 plot_feature_importance 을 이용
#         - 변수중요도 파악및 결과 저장

# %% [markdown]
# #### 1) 데이터 전처리

# %%
# 데이터 분할을 위한 전처리
target = 'Activity'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3,random_state=2025)

# %% [markdown]
# #### 2) 모델링

# %%
#생성
model = RandomForestClassifier(random_state=2025)

#학습
model.fit(x_train, y_train)
pred = model.predict(x_val)

#평가
print('accuracy :',accuracy_score(y_val, pred))
print('='*60)
print(confusion_matrix(y_val, pred))
print('='*60)
print(classification_report(y_val, pred))
# Out:
# accuracy : 0.9705382436260623
# ============================================================
# [[346   0   0   0   0   0]
#  [  0 275  17   0   0   0]
#  [  0  19 339   0   0   0]
#  [  0   0   0 291   2   2]
#  [  0   0   0   3 221   2]
#  [  0   0   0   2   5 241]]
# ============================================================
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       346
#            SITTING       0.94      0.94      0.94       292
#           STANDING       0.95      0.95      0.95       358
#            WALKING       0.98      0.99      0.98       295
# WALKING_DOWNSTAIRS       0.97      0.98      0.97       226
#   WALKING_UPSTAIRS       0.98      0.97      0.98       248
#
#           accuracy                           0.97      1765
#          macro avg       0.97      0.97      0.97      1765
#       weighted avg       0.97      0.97      0.97      1765

# %% [markdown]
# #### 3) 변수 중요도 추출

# %%
# 변수 중요도 추출
r0 = plot_feature_importance(model.feature_importances_, list(x_train), False)
r0
# Out:
#                            feature_name  feature_importance
# 0                   tGravityAcc-max()-X            0.037513
# 1                  tGravityAcc-mean()-X            0.031618
# 2                  angle(Y,gravityMean)            0.030671
# 3                tGravityAcc-energy()-X            0.029401
# 4                   tGravityAcc-max()-Y            0.028310
# ..                                  ...                 ...
# 556      fBodyAcc-bandsEnergy()-57,64.1            0.000071
# 557      fBodyAcc-bandsEnergy()-33,48.1            0.000070
# 558  fBodyAccJerk-bandsEnergy()-57,64.2            0.000059
# 559                tGravityAccMag-min()            0.000047
# 560              tBodyGyroMag-entropy()            0.000043
#
# [561 rows x 2 columns]

# %% [markdown]
# ### (2) 중요도 기반 feature 분석

# %% [markdown]
# * **세부 요구사항**
#     - 상위 n, 하위 m 개의 변수를 선정
#     - 선정된 변수(feature)와 target 간의 관계를 kdeplot으로 그리기

# %% [markdown]
# #### 1) 상위 5, 하위 5개 변수 선정

# %%
# 중요도 상위 top 5
r0.head(5)
# Out:
#              feature_name  feature_importance
# 0     tGravityAcc-max()-X            0.037513
# 1    tGravityAcc-mean()-X            0.031618
# 2    angle(Y,gravityMean)            0.030671
# 3  tGravityAcc-energy()-X            0.029401
# 4     tGravityAcc-max()-Y            0.028310

# %%
# 중요도 하위 top 5
r0.tail(5)
# Out:
#                            feature_name  feature_importance
# 556      fBodyAcc-bandsEnergy()-57,64.1            0.000071
# 557      fBodyAcc-bandsEnergy()-33,48.1            0.000070
# 558  fBodyAccJerk-bandsEnergy()-57,64.2            0.000059
# 559                tGravityAccMag-min()            0.000047
# 560              tBodyGyroMag-entropy()            0.000043

# %% [markdown]
# #### 2) 상위 5개 변수에 대한 분석

# %%
# 1위 : tGravityAcc-max()-X
var = 'tGravityAcc-max()-X'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tGravityAcc-max()-X', ylabel='Density'>

# %%
# 2위 : tGravityAcc-mean()-X
var = 'tGravityAcc-mean()-X'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tGravityAcc-mean()-X', ylabel='Density'>

# %%
# 3위 :angle(Y,gravityMean)
var = 'angle(Y,gravityMean)'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='angle(Y,gravityMean)', ylabel='Density'>

# %%
# 4위 :tGravityAcc-energy()-X
var = 'tGravityAcc-energy()-X'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tGravityAcc-energy()-X', ylabel='Density'>

# %%
# 5위 : tGravityAcc-max()-Y
var = 'tGravityAcc-max()-Y'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tGravityAcc-max()-Y', ylabel='Density'>

# %% [markdown]
# #### 3) 하위 5개 변수에 대한 분석

# %%
# 1위 : fBodyAcc-bandsEnergy()-57,64.1
var = 'fBodyAcc-bandsEnergy()-57,64.1'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAcc-bandsEnergy()-57,64.1', ylabel='Density'>

# %%
# 2위 :fBodyAcc-bandsEnergy()-33,48.1
var = 'fBodyAcc-bandsEnergy()-33,48.1'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAcc-bandsEnergy()-33,48.1', ylabel='Density'>

# %%
# 3위 :fBodyAccJerk-bandsEnergy()-57,64.2
var = 'fBodyAccJerk-bandsEnergy()-57,64.2'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAccJerk-bandsEnergy()-57,64.2', ylabel='Density'>

# %%
# 4위 :tGravityAccMag-min()
var = 'tGravityAccMag-min()'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tGravityAccMag-min()', ylabel='Density'>

# %%
# 5위 :tBodyGyroMag-entropy()
var = 'tBodyGyroMag-entropy()'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tBodyGyroMag-entropy()', ylabel='Density'>

# %% [markdown]
# ## 4.미션2 : 데이터 분석2

# %% [markdown]
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ### (1) 정적/동적 행동으로 구분하여 분석하기

# %% [markdown]
# * **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.

# %% [markdown]
# #### 1) is_dynamic 추가

# %%
is_dynamic = y.map({'STANDING':0, 'SITTING':0, 'LAYING':0,
                  'WALKING':1, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':1})
is_dynamic
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 5876    0
# 5877    1
# 5878    0
# 5879    1
# 5880    0
# Name: Activity, Length: 5881, dtype: int64

# %% [markdown]
# #### 2) 기본모델 생성

# %%
#데이터 분할 진행(train:val = 8:2 혹은 7:3 권장)
x_train, x_val, y_train, y_val = train_test_split(x, is_dynamic, test_size = .3,random_state=2025)

# %%
#RandomForestClassifier로 모델링 진행
model = RandomForestClassifier(random_state=2025)
model.fit(x_train, y_train)
pred = model.predict(x_val)

print('accuracy :',accuracy_score(y_val, pred))
print('='*60)
print(confusion_matrix(y_val, pred))
print('='*60)
print(classification_report(y_val, pred))
# Out:
# accuracy : 1.0
# ============================================================
# [[996   0]
#  [  0 769]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       996
#            1       1.00      1.00      1.00       769
#
#     accuracy                           1.00      1765
#    macro avg       1.00      1.00      1.00      1765
# weighted avg       1.00      1.00      1.00      1765

# %% [markdown]
# #### 3) 변수중요도 상위 5개 분석

# %%
r_dyn = plot_feature_importance(model.feature_importances_, list(x_train), False)
r_dyn
# Out:
#                         feature_name  feature_importance
# 0     fBodyAccJerk-bandsEnergy()-1,8            0.050079
# 1               fBodyAccJerk-max()-X            0.050049
# 2          tBodyAccJerkMag-entropy()            0.049991
# 3             tBodyAccJerkMag-mean()            0.049871
# 4    fBodyAccJerk-bandsEnergy()-1,16            0.040205
# ..                               ...                 ...
# 556                tBodyGyro-mad()-X            0.000000
# 557                tBodyGyro-std()-Z            0.000000
# 558                tBodyGyro-std()-Y            0.000000
# 559                tBodyGyro-std()-X            0.000000
# 560                fBodyAcc-mean()-Y            0.000000
#
# [561 rows x 2 columns]

# %% [markdown]
# * 상위 변수 선정

# %%
r_dyn.head()
# Out:
#                       feature_name  feature_importance
# 0   fBodyAccJerk-bandsEnergy()-1,8            0.050079
# 1             fBodyAccJerk-max()-X            0.050049
# 2        tBodyAccJerkMag-entropy()            0.049991
# 3           tBodyAccJerkMag-mean()            0.049871
# 4  fBodyAccJerk-bandsEnergy()-1,16            0.040205

# %% [markdown]
# * 중요도 상위 변수 데이터 탐색하기

# %%
temp = x.copy()
temp['is_dynamic'] = is_dynamic
target = 'is_dynamic'

# %%
# 1위 :fBodyAccJerk-bandsEnergy()-1,8
var = 'fBodyAccJerk-bandsEnergy()-1,8'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = temp, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAccJerk-bandsEnergy()-1,8', ylabel='Density'>

# %%
# 2위 : fBodyAccJerk-max()-X
var = 'fBodyAccJerk-max()-X'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = temp, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAccJerk-max()-X', ylabel='Density'>

# %%
# 3위 : tBodyAccJerkMag-entropy()
var = 'tBodyAccJerkMag-entropy()'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = temp, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tBodyAccJerkMag-entropy()', ylabel='Density'>

# %%
# 4위 : tBodyAccJerkMag-mean()
var = 'tBodyAccJerkMag-mean()'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = temp, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='tBodyAccJerkMag-mean()', ylabel='Density'>

# %%
# 5위 :fBodyAccJerk-bandsEnergy()-1,16
var = 'fBodyAccJerk-bandsEnergy()-1,16'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = temp, hue =target, common_norm = False)
# Out:
# <Axes: xlabel='fBodyAccJerk-bandsEnergy()-1,16', ylabel='Density'>

# %% [markdown]
# ## 5.특성 중요도 저장하기

# %% [markdown]
# * **세부 요구사항**
#     - 지금까지 변수 중요도를 다양한 관점에서 뽑고 분석을 해 보았습니다.
#         - 관점1 : 6개 행동 구분
#         - 관점2 : 동적, 정적 행동 구분
#     - 모든 관점의 변수 중요도를 하나로 합친 후 저장
#         - merge를 이용하여 features와 합칩니다.
#         - joblib 패키지의 dump를 이용하여 결과를 저장합니다.

# %% [markdown]
# ### (1) 하나로 합치기
# * 합치기 위해서는 중요도 결과에서 feature_importance 칼럼 이름을 수정해야 합니다.
# * pd.merge를 이용해서 하나씩 합치는 작업을 반복 합니다.

# %% [markdown]
# #### 1) 이름변경

# %%
r0.rename(columns={'feature_importance':'fi_all'}, inplace=True)
r_dyn.rename(columns={'feature_importance':'fi_dynamic'}, inplace=True)

# %% [markdown]
# #### 2) 합치기

# %%
result = pd.merge(features, r0)
result = pd.merge(result, r_dyn)
result.head()
# Out:
#      sensor     agg axis       feature_name    fi_all  fi_dynamic
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X  0.000244    0.000087
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y  0.000276    0.000000
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z  0.000330    0.000030
# 3  tBodyAcc   std()    X   tBodyAcc-std()-X  0.006407    0.009863
# 4  tBodyAcc   std()    Y   tBodyAcc-std()-Y  0.000559    0.000029

# %% [markdown]
# ### (2) 저장하기
# * joblib.dump를 이용하시오.
# * 저장할 파일의 확장자는 보통 .pkl 입니다.

# %%
import joblib

joblib.dump(result, path + 'fi_analysis.pkl')
# Out:
# ['/content/drive/MyDrive/project3/fi_analysis.pkl']

# %%
joblib.load(path + 'fi_analysis.pkl')
# Out:
#        sensor                agg         axis  \
# 0    tBodyAcc             mean()            X
# 1    tBodyAcc             mean()            Y
# 2    tBodyAcc             mean()            Z
# 3    tBodyAcc              std()            X
# 4    tBodyAcc              std()            Y
# ..        ...                ...          ...
# 556     angle      tBodyGyroMean  gravityMean
# 557     angle  tBodyGyroJerkMean  gravityMean
# 558     angle                  X  gravityMean
# 559     angle                  Y  gravityMean
# 560     angle                  Z  gravityMean
#
#                              feature_name    fi_all  fi_dynamic
# 0                       tBodyAcc-mean()-X  0.000244    0.000087
# 1                       tBodyAcc-mean()-Y  0.000276    0.000000
# 2                       tBodyAcc-mean()-Z  0.000330    0.000030
# 3                        tBodyAcc-std()-X  0.006407    0.009863
# 4                        tBodyAcc-std()-Y  0.000559    0.000029
# ..                                    ...       ...         ...
# 556      angle(tBodyGyroMean,gravityMean)  0.000609    0.000000
# 557  angle(tBodyGyroJerkMean,gravityMean)  0.000419    0.000000
# 558                  angle(X,gravityMean)  0.019354    0.000010
# 559                  angle(Y,gravityMean)  0.030671    0.000029
# 560                  angle(Z,gravityMean)  0.010840    0.000078
#
# [561 rows x 6 columns]
